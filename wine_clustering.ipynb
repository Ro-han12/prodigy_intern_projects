# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("wine-clustering.csv")
data.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline
# 0   3.92     1065
# 1   3.40     1050
# 2   3.17     1185
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alcohol               178 non-null    float64
#  1   Malic_Acid            178 non-null    float64
#  2   Ash                   178 non-null    float64
#  3   Ash_Alcanity          178 non-null    float64
#  4   Magnesium             178 non-null    int64
#  5   Total_Phenols         178 non-null    float64
#  6   Flavanoids            178 non-null    float64
#  7   Nonflavanoid_Phenols  178 non-null    float64
#  8   Proanthocyanins       178 non-null    float64
#  9   Color_Intensity       178 non-null    float64
#  10  Hue                   178 non-null    float64
#  11  OD280                 178 non-null    float64
#  12  Proline               178 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 18.2 KB

# %%
data.isnull().sum()
# Out:
# Alcohol                 0
# Malic_Acid              0
# Ash                     0
# Ash_Alcanity            0
# Magnesium               0
# Total_Phenols           0
# Flavanoids              0
# Nonflavanoid_Phenols    0
# Proanthocyanins         0
# Color_Intensity         0
# Hue                     0
# OD280                   0
# Proline                 0
# dtype: int64

# %%
data.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
# ...

# %%
data.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline
# 0   3.92     1065
# 1   3.40     1050
# 2   3.17     1185
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
features=sc.fit(data)
features=features.transform(data)

# %%
df=pd.DataFrame(features,columns=data.columns)
df.head()
# Out:
#     Alcohol  Malic_Acid       Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0  1.518613   -0.562250  0.232053     -1.169593   1.913905       0.808997
# 1  0.246290   -0.499413 -0.827996     -2.490847   0.018145       0.568648
# 2  0.196879    0.021231  1.109334     -0.268738   0.088358       0.808997
# 3  1.691550   -0.346811  0.487926     -0.809251   0.930918       2.491446
# 4  0.295700    0.227694  1.840403      0.451946   1.281985       0.808997
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# 0    1.034819             -0.659563         1.224884         0.251717
# 1    0.733629             -0.820719        -0.544721        -0.293321
# 2    1.215533             -0.498407         2.135968         0.269020
# 3    1.466525             -0.981875         1.032155         1.186068
# 4    0.663351              0.226796         0.401404        -0.319276
#
#         Hue     OD280   Proline
# 0  0.362177  1.847920  1.013009
# 1  0.406051  1.113449  0.965242
# ...

# %%
x=df.drop('Alcohol',axis=1)
y=df['Alcohol']

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt 
wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i,init='k-means++',random_state=42)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.show()
# Out:
# /Users/rohansridhar/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/rohansridhar/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/rohansridhar/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
selected=df[['Alcohol','Proline']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.cluster import KMeans
knn=KMeans(n_clusters=3,init='k-means++',random_state=42)
knn.fit(selected)
# Out:
# /Users/rohansridhar/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=3, random_state=42)

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
pca.fit_transform(x)
# Out:
# array([[-3.07857252e+00, -1.21926180e+00],
#        [-2.19079587e+00,  6.64568240e-01],
#        [-2.45644079e+00, -1.50581110e+00],
#        [-3.42275012e+00, -2.55605831e+00],
#        [-9.48975875e-01, -1.32973488e+00],
#        [-2.76731538e+00, -1.77985016e+00],
#        [-2.18375478e+00, -4.58036710e-01],
#        [-1.82632140e+00, -1.33985744e+00],
#        [-2.19383381e+00,  2.03202783e-01],
#        [-2.59000186e+00, -4.35609334e-01],
#        [-3.26089058e+00, -1.03803643e+00],
#        [-1.55488981e+00,  1.04878503e-01],
#        [-1.96567565e+00, -2.73148206e-01],
#        [-3.14743458e+00, -2.58202082e-01],
#        [-4.00629989e+00, -1.65773346e+00],
#        [-2.13051424e+00, -1.67993499e+00],
#        [-1.87351026e+00, -2.15937482e+00],
#        [-1.70365337e+00, -1.62849380e+00],
#        [-3.23817800e+00, -2.25696066e+00],
#        [-1.94408078e+00, -9.99518957e-01],
#        [-2.94642239e+00, -5.67121964e-01],
#        [-1.09489837e+00, -6.02002492e-01],
# ...

# %%
dataset=pd.DataFrame(data1,columns=['pca1','pca2'])
dataset.head()
# Out:
#        pca1      pca2
# 0  3.316751 -1.443463
# 1  2.209465  0.333393
# 2  2.516740 -1.031151
# 3  3.757066 -2.756372
# 4  1.008908 -0.869831

# %%
centers=pca.transform(kmeans.cluster_centers_)
centers
# Out:
# /Users/rohansridhar/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but PCA was fitted with feature names
#   warnings.warn(
# array([[-1.68337763, -1.47933262],
#        [ 3.02057531, -0.71764599],
#        [-0.46448198,  2.10518411],
#        [-2.69961996, -1.13624237],
#        [ 1.3974405 ,  1.55374105],
#        [-1.7788788 ,  0.11958886],
#        [ 0.76354507,  1.3760086 ],
#        [ 2.27839924, -1.40767845],
#        [-2.08227732, -0.02533088],
#        [-1.23226449,  0.50178516]])

# %%
plt.scatter(x=dataset['pca1'],y=dataset['pca2'],c=kmeans.labels_)
plt.scatter(centers[:,0],centers[:,1],marker='x',c='red')
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.title('Wine Cluster')
plt.tight_layout()

# %%
plt.figure(figsize=(7,5))
plt.scatter(x=selected['Proline'],y=selected['Alcohol'],c=knn.labels_)
plt.scatter(knn.cluster_centers_[:,0],knn.cluster_centers_[:,1],marker='x',c='red',s=100)
